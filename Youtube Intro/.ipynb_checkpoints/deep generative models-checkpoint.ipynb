# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# latent variables-> not true but are responsible for it]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
